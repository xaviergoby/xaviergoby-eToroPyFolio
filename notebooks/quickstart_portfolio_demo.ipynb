# %%
# %matplotlib inline
from src.portfolio import Portfolio

# %%
portfolio_xlsx_file_name = "eToroAccountStatementLatest.xlsx"
# portfolio_xlsx_file_name = "eeToroAccountStatement_DEMO.xlsx"
portfolio = Portfolio(portfolio_xlsx_file_name)
# Out:
# - BTC: 1d data not available for startTime=-2208988800 and endTime=1612538391. Only 100 years worth of day granularity data are allowed to be fetched per request.
# - SAOC: No data found, symbol may be delisted
# C:\Users\Xavier\eToroPyFolio\src\xlsx_file_parser_improved.py:148: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.

# %%
portfolio.plot_daily_returns()
# Out:
# <div>                            <div id="24535960-8e57-4f86-953a-eef57b8cc122" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("24535960-8e57-4f86-953a-eef57b8cc122")) {                    Plotly.newPlot(                        "24535960-8e57-4f86-953a-eef57b8cc122",                        [{"type": "scatter", "x": ["2020-01-01T00:00:00", "2020-01-02T00:00:00", "2020-01-03T00:00:00", "2020-01-04T00:00:00", "2020-01-05T00:00:00", "2020-01-06T00:00:00", "2020-01-07T00:00:00", "2020-01-08T00:00:00", "2020-01-09T00:00:00", "2020-01-10T00:00:00", "2020-01-11T00:00:00", "2020-01-12T00:00:00", "2020-01-13T00:00:00", "2020-01-14T00:00:00", "2020-01-15T00:00:00", "2020-01-16T00:00:00", "2020-01-17T00:00:00", "2020-01-18T00:00:00", "2020-01-19T00:00:00", "202
# ...

# %%
portfolio.closed_orders.plot_daily_returns()
# Out:
# <div>                            <div id="780d8709-e692-4134-9ee6-400f414f8d2d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("780d8709-e692-4134-9ee6-400f414f8d2d")) {                    Plotly.newPlot(                        "780d8709-e692-4134-9ee6-400f414f8d2d",                        [{"type": "scatter", "x": ["2020-05-27T00:00:00", "2020-05-28T00:00:00", "2020-05-29T00:00:00", "2020-06-01T00:00:00", "2020-06-02T00:00:00", "2020-06-03T00:00:00", "2020-06-04T00:00:00", "2020-06-05T00:00:00", "2020-06-08T00:00:00", "2020-06-09T00:00:00", "2020-06-10T00:00:00", "2020-06-11T00:00:00", "2020-06-12T00:00:00", "2020-06-15T00:00:00", "2020-06-16T00:00:00", "2020-06-17T00:00:00", "2020-06-18T00:00:00", "2020-06-19T00:00:00", "2020-06-22T00:00:00", "202
# ...

# %%
portfolio.closed_orders.plot_daily_returns()

print(portfolio.closed_orders.pos_daily_returns_df)
res = portfolio.closed_orders.pos_daily_returns_df.dropna()
print(res)
# Out:
# <div>                            <div id="852d4dde-4d5c-4c1b-a55c-706cf5b92b65" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("852d4dde-4d5c-4c1b-a55c-706cf5b92b65")) {                    Plotly.newPlot(                        "852d4dde-4d5c-4c1b-a55c-706cf5b92b65",                        [{"type": "scatter", "x": ["2020-05-27T00:00:00", "2020-05-28T00:00:00", "2020-05-29T00:00:00", "2020-06-01T00:00:00", "2020-06-02T00:00:00", "2020-06-03T00:00:00", "2020-06-04T00:00:00", "2020-06-05T00:00:00", "2020-06-08T00:00:00", "2020-06-09T00:00:00", "2020-06-10T00:00:00", "2020-06-11T00:00:00", "2020-06-12T00:00:00", "2020-06-15T00:00:00", "2020-06-16T00:00:00", "2020-06-17T00:00:00", "2020-06-18T00:00:00", "2020-06-19T00:00:00", "2020-06-22T00:00:00", "202
# ...

# %%
portfolio.closed_orders.closed_pos_daily_rets
# Out:
# Date
# 2020-05-27      0.000000
# 2020-05-28      6.064179
# 2020-05-29     26.212826
# 2020-06-01     24.550090
# 2020-06-02     23.669806
#                  ...
# 2020-12-08    297.353452
# 2020-12-09    283.169439
# 2020-12-10    287.825411
# 2020-12-11    277.362706
# 2020-12-14    271.634765
# Length: 141, dtype: float64

# %%
portfolio.closed_orders.pos_daily_returns_df.na
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-5ba91bcf6ec5> in <module>
# ----> 1 portfolio.closed_orders.pos_daily_returns_df.na
#       2
#
# c:\users\xavier\etoropyfolio\venv\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5139             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5140                 return self[name]
# -> 5141             return object.__getattribute__(self, name)
#    5142
#    5143     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'na'

# %%
print(portfolio.acc_details)
